# %%
import json

def findfraud(NAME):
    with open(NAME + '.json', encoding="utf8") as f:
        x = json.load(f)
    TotalVotesLostTrump = 0
    TotalVotesLostBiden = 0
    TrumpToThird = 0
    TrumpToBiden = 0
    BidenToTrump = 0
    ThirdToTrump = 0
    ThirdToBiden = 0
    BidenToThird = 0
    TotalVotesLostThird = 0
    series = x["data"]["races"][0]["timeseries"]
    for i in range(len(series)):
            thirdPartyNow = series[i]["votes"] * (1 - series[i]["vote_shares"]["bidenj"] - series[i]["vote_shares"]["trumpd"])
            thirdPartyThen = series[i-1]["votes"] * (1 - series[i-1]["vote_shares"]["bidenj"] - series[i-1]["vote_shares"]["trumpd"])
            TrumpNow = series[i]["votes"] * series[i]["vote_shares"]["trumpd"]
            TrumpThen = series[i-1]["votes"] * series[i-1]["vote_shares"]["trumpd"]
            BidenNow = series[i]["votes"] * series[i]["vote_shares"]["bidenj"]
            BidenThen = series[i-1]["votes"] * series[i-1]["vote_shares"]["bidenj"]
            if i != 0 and TrumpNow < TrumpThen and (TrumpThen - TrumpNow) > (0.00049999 * series[i]["votes"]) + 50:
                if BidenNow > BidenThen or thirdPartyNow > thirdPartyThen:
                    if TrumpNow - TrumpThen <= BidenNow - BidenThen or TrumpNow - TrumpThen <= thirdPartyNow - thirdPartyThen:
                        print ("(TRUMP")
                        print ("Index : " + str(i) + " Past Index : " + str(i-1))
                        print (TrumpNow - TrumpThen)
                        TrumpLostNow = TrumpThen - TrumpNow
                        TrumpLostTotal = TrumpThen - TrumpNow
                        if BidenNow > BidenThen and TrumpNow - TrumpThen <= BidenNow - BidenThen:
                            if BidenNow - BidenThen > TrumpLostTotal:
                                TrumpToBiden += TrumpLostTotal
                                TrumpLostTotal = 0
                            else:
                                TrumpToBiden += BidenNow - BidenThen
                                TrumpLostTotal -= BidenNow - BidenThen
                        if thirdPartyNow > thirdPartyThen and TrumpNow - TrumpThen <= thirdPartyNow - thirdPartyThen:
                            if thirdPartyNow - thirdPartyThen > TrumpLostTotal:
                                TrumpToThird += TrumpLostTotal
                                TrumpLostTotal = 0
                            else:
                                TrumpToThird += thirdPartyNow - thirdPartyThen
                                TrumpLostTotal -= thirdPartyNow - thirdPartyThen
                        if TrumpLostNow < 0:
                            TrumpLostNow = 0
                        TotalVotesLostTrump += TrumpLostNow - TrumpLostTotal
                        print ("TRUMP)")
            if i != 0 and BidenNow < BidenThen and (BidenThen - BidenNow) > (0.00049999 * series[i]["votes"]) + 50:
                if TrumpNow > TrumpThen or thirdPartyNow > thirdPartyThen:
                    if BidenNow - BidenThen <= TrumpNow - TrumpThen or BidenNow - BidenThen <= thirdPartyNow - thirdPartyThen:
                        print ("(BIDEN")
                        print ("Index : " + str(i) + " Past Index : " + str(i-1))
                        print (BidenNow - BidenThen)
                        BidenLostNow = BidenThen - BidenNow
                        BidenLostTotal = BidenThen - BidenNow
                        if TrumpNow > TrumpThen and BidenNow - BidenThen <= TrumpNow - TrumpThen:
                            if TrumpNow - TrumpThen > BidenLostTotal:
                                BidenToTrump += BidenLostTotal
                                BidenLostTotal = 0
                            else:
                                BidenToTrump += TrumpNow - TrumpThen
                                BidenLostTotal -= TrumpNow - TrumpThen
                        if thirdPartyNow > thirdPartyThen and BidenNow - BidenThen <= thirdPartyNow - thirdPartyThen:
                            if thirdPartyNow - thirdPartyThen > BidenLostTotal:
                                BidenToThird += BidenLostTotal
                                BidenLostTotal = 0
                            else:
                                BidenToThird += thirdPartyNow - thirdPartyThen
                                BidenLostTotal -= thirdPartyNow - thirdPartyThen
                        if BidenLostNow < 0:
                            BidenLostNow = 0
                        TotalVotesLostBiden += BidenLostNow - BidenLostTotal
                        print ("BIDEN)")
            if i!= 0 and thirdPartyNow < thirdPartyThen and (thirdPartyThen - thirdPartyNow) > (0.00049999 * series[i]["votes"]) + 50:
                if thirdPartyNow < thirdPartyThen:
                    if thirdPartyNow - thirdPartyThen <= TrumpNow - TrumpThen or thirdPartyNow - thirdPartyThen <= BidenNow - BidenThen:
                        print("(3RD PARTY")
                        print("Index : " + str(i) + " Past Index : " + str(i-1))
                        print (thirdPartyNow - thirdPartyThen)
                        ThirdLostTotal = thirdPartyThen - thirdPartyNow
                        ThirdLostNow = thirdPartyThen - thirdPartyNow
                        if BidenNow > BidenThen and thirdPartyNow - thirdPartyThen <= BidenNow - BidenThen:
                            if BidenNow - BidenThen > ThirdLostTotal:
                                ThirdToBiden += ThirdLostTotal
                                ThirdLostTotal = 0
                            else:
                                ThirdToBiden += BidenNow - BidenThen
                                ThirdLostTotal -= BidenNow - BidenThen
                        if TrumpNow > TrumpThen and thirdPartyNow - thirdPartyThen <= TrumpNow - TrumpThen:
                            if TrumpNow - TrumpThen > ThirdLostTotal:
                                ThirdToTrump += ThirdLostTotal
                                ThirdLostTotal = 0
                            else:
                                ThirdToTrump += TrumpNow - TrumpThen
                                ThirdLostTotal -= TrumpNow - TrumpThen
                        if ThirdLostNow < 0:
                            ThirdLostNow = 0
                        TotalVotesLostThird += ThirdLostNow - ThirdLostTotal
                        print ("3RD PARTY)")
    print (str(str(TotalVotesLostTrump)  + " TRUMP LOST"))
    print (str(TrumpToBiden) + " Trump to Biden")
    print (str(TrumpToThird) + " Trump to Third")
    print (str(str(TotalVotesLostBiden)  + " BIDEN LOST"))
    print (str(BidenToTrump) + " Biden to Trump")
    print (str(BidenToThird) + " Biden to Third")
    print (str(str(TotalVotesLostThird)  + " 3RD PARTY LOST"))
    print (str(ThirdToBiden) + " Third to Biden")
    print (str(ThirdToTrump) + " Third to Trump")
    if BidenToTrump > TrumpToBiden:
        print (str(BidenToTrump - TrumpToBiden) + " TRUMP")
    elif TrumpToBiden > BidenToTrump:
        print (str(TrumpToBiden - BidenToTrump) + " BIDEN")

# %%
def lostvotes(NAME):
    with open(NAME + '.json', encoding="utf8") as f:
        x = json.load(f)
    TotalVotesLost = 0
    TotalVotesLostBiden = 0
    TotalVotesLostTrump = 0
    TotalVotesLostThird = 0
    series = x["data"]["races"][0]["timeseries"]
    for i in range(len(series)):
        thirdPartyNow =  1 - series[i]["vote_shares"]["bidenj"] - series[i]["vote_shares"]["trumpd"]
        thirdPartyThen = 1 - series[i-1]["vote_shares"]["bidenj"] - series[i-1]["vote_shares"]["trumpd"]
        if (series[i]["vote_shares"]["bidenj"] < (series[i-1]["vote_shares"]["bidenj"] - 0.001) or series[i]["vote_shares"]["bidenj"] > (series[i-1]["vote_shares"]["bidenj"] + 0.001)) and (series[i]["vote_shares"]["trumpd"] < (series[i-1]["vote_shares"]["trumpd"] - 0.001) or series[i]["vote_shares"]["trumpd"] > (series[i-1]["vote_shares"]["trumpd"] + 0.001)):
            if i != 0 and series[i]["votes"] < series[i-1]["votes"] and series[i]["votes"] * series[i]["vote_shares"]["bidenj"] < series[i-1]["votes"] * series[i-1]["vote_shares"]["bidenj"] and series[i]["votes"] * series[i]["vote_shares"]["trumpd"] < series[i-1]["votes"] * series[i-1]["vote_shares"]["trumpd"]:
                TotalVotesLost += series[i]["votes"] - series[i-1]["votes"]
                print ("Index : " + str(i) + " Past Index : " + str(i-1))
                print (series[i]["votes"] - series[i-1]["votes"])
                TotalVotesLostTrump += series[i]["votes"] * series[i]["vote_shares"]["trumpd"] - series[i-1]["votes"] * series[i-1]["vote_shares"]["trumpd"]
                TotalVotesLostBiden += series[i]["votes"] * series[i]["vote_shares"]["bidenj"] - series[i-1]["votes"] * series[i-1]["vote_shares"]["bidenj"]
                TotalVotesLostThird += series[i]["votes"] * thirdPartyNow - series[i-1]["votes"] * thirdPartyThen
    print (str(TotalVotesLostTrump) + " TRUMP")
    print (str(TotalVotesLostBiden) + " BIDEN")
    print (str(TotalVotesLostThird) + " THIRD")
    print (TotalVotesLost)

# %%
findfraud('AZ_president')
# Out:
# (3RD PARTY
# Index : 7 Past Index : 6
# -2305.483000000004
# 3RD PARTY)
# (TRUMP
# Index : 8 Past Index : 7
# -2291.2409999999218
# TRUMP)
# (BIDEN
# Index : 9 Past Index : 8
# -1668.8349999999627
# BIDEN)
# (3RD PARTY
# Index : 12 Past Index : 11
# -2215.346999999998
# 3RD PARTY)
# (BIDEN
# Index : 18 Past Index : 17
# -1346.1060000001453
# BIDEN)
# (3RD PARTY
# Index : 21 Past Index : 20
# -2348.0660000000025
# 3RD PARTY)
# (BIDEN
# Index : 22 Past Index : 21
# -1723.0260000000708
# BIDEN)
# (3RD PARTY
# Index : 24 Past Index : 23
# -1596.792000000005
# 3RD PARTY)
# (3RD PARTY
# Index : 28 Past Index : 27
# -2365.481000000007
# 3RD PARTY)
# (3RD PARTY
# Index : 31 Past Index : 30
# -2367.734000000004
# 3RD PARTY)
# (3RD PARTY
# Index : 37 Past Index : 36
# -2422.9539999998597
# 3RD PARTY)
# (TRUMP
# Index : 38 Past Index : 37
# -2201.0439999999944
# TRUMP)
# (3RD PARTY
# Index : 52 Past Index : 51
# -2851.0120000000024
# 3RD PARTY)
# (BIDEN
# Index : 53 Past Index : 52
# -2116.304999999935
# BIDEN)
# (3RD PARTY
# Index : 58 Past Index : 57
# -2942.9400000000023
# 3RD PARTY)
# (BIDEN
# Index : 74 Past Index : 73
# -1670.4189999999944
# BIDEN)
# (3RD PARTY
# Index : 80 Past Index : 79
# -5841.878000000004
# 3RD PARTY)
# (3RD PARTY
# Index : 89 Past Index : 88
# -3106.4320000000007
# 3RD PARTY)
# (3RD PARTY
# Index : 102 Past Index : 101
# -3252.855000000003
# 3RD PARTY)
# (BIDEN
# Index : 103 Past Index : 102
# -2889.0190000000875
# BIDEN)
# (3RD PARTY
# Index : 111 Past Index : 110
# -3156.578999999998
# 3RD PARTY)
# 4492.284999999916 TRUMP LOST
# 532.839999999851 Trump to Biden
# 3959.445000000065 Trump to Third
# 11413.710000000196 BIDEN LOST
# 4917.905999999959 Biden to Trump
# 6495.804000000237 Biden to Third
# 36773.55299999989 3RD PARTY LOST
# 35530.15799999998 Third to Biden
# 1243.3949999999095 Third to Trump
# 4385.066000000108 TRUMP

# %%
findfraud('GA_president')
# Out:
# (3RD PARTY
# Index : 4 Past Index : 3
# -169.59000000000015
# 3RD PARTY)
# (3RD PARTY
# Index : 15 Past Index : 14
# -206.62400000000025
# 3RD PARTY)
# (3RD PARTY
# Index : 25 Past Index : 24
# -269.1940000000004
# 3RD PARTY)
# (3RD PARTY
# Index : 28 Past Index : 27
# -269.4310000000319
# 3RD PARTY)
# (BIDEN
# Index : 29 Past Index : 28
# -256.2730000000156
# BIDEN)
# (3RD PARTY
# Index : 39 Past Index : 38
# -423.6750000000011
# 3RD PARTY)
# (3RD PARTY
# Index : 47 Past Index : 46
# -467.5450000000001
# 3RD PARTY)
# (3RD PARTY
# Index : 49 Past Index : 48
# -572.0560000000005
# 3RD PARTY)
# (BIDEN
# Index : 52 Past Index : 51
# -571.5939999999828
# BIDEN)
# (TRUMP
# Index : 53 Past Index : 52
# -446.65299999999115
# TRUMP)
# (3RD PARTY
# Index : 54 Past Index : 53
# -501.39100000008966
# 3RD PARTY)
# (3RD PARTY
# Index : 58 Past Index : 57
# -723.612000000001
# 3RD PARTY)
# (BIDEN
# Index : 63 Past Index : 62
# -600.9519999999902
# BIDEN)
# (3RD PARTY
# Index : 98 Past Index : 97
# -1578.4670000000024
# 3RD PARTY)
# (3RD PARTY
# Index : 101 Past Index : 100
# -1597.2279999999992
# 3RD PARTY)
# (3RD PARTY
# Index : 109 Past Index : 108
# -1659.809000000001
# 3RD PARTY)
# (3RD PARTY
# Index : 112 Past Index : 111
# -1690.2580000000016
# 3RD PARTY)
# (3RD PARTY
# Index : 116 Past Index : 115
# -1696.0030000000006
# 3RD PARTY)
# (3RD PARTY
# Index : 126 Past Index : 125
# -1904.1539999999986
# 3RD PARTY)
# (3RD PARTY
# Index : 130 Past Index : 129
# -1128.766000000218
# 3RD PARTY)
# (BIDEN
# Index : 142 Past Index : 141
# -1296.9640000000363
# BIDEN)
# (3RD PARTY
# Index : 143 Past Index : 142
# -2192.1620000000003
# 3RD PARTY)
# (3RD PARTY
# Index : 151 Past Index : 150
# -2316.0750000000007
# 3RD PARTY)
# (3RD PARTY
# Index : 155 Past Index : 154
# -2472.671000000002
# 3RD PARTY)
# (3RD PARTY
# Index : 161 Past Index : 160
# -1532.6270000002805
# 3RD PARTY)
# (3RD PARTY
# Index : 165 Past Index : 164
# -2622.898000000001
# 3RD PARTY)
# (3RD PARTY
# Index : 167 Past Index : 166
# -2430.709000000006
# 3RD PARTY)
# (3RD PARTY
# Index : 170 Past Index : 169
# -2685.9990000003054
# 3RD PARTY)
# (3RD PARTY
# Index : 204 Past Index : 203
# -3044.1470000000045
# 3RD PARTY)
# (3RD PARTY
# Index : 209 Past Index : 208
# -2260.055000000364
# 3RD PARTY)
# (3RD PARTY
# Index : 227 Past Index : 226
# -3375.072999999611
# 3RD PARTY)
# (BIDEN
# Index : 228 Past Index : 227
# -2731.102000000188
# BIDEN)
# (3RD PARTY
# Index : 229 Past Index : 228
# -3476.8939999996
# 3RD PARTY)
# (TRUMP
# Index : 237 Past Index : 236
# -3741.96399999992
# TRUMP)
# (3RD PARTY
# Index : 238 Past Index : 237
# -3772.4720000000016
# 3RD PARTY)
# (3RD PARTY
# Index : 247 Past Index : 246
# -3378.1009999995586
# 3RD PARTY)
# (TRUMP
# Index : 249 Past Index : 248
# -3907.526000000071
# TRUMP)
# (3RD PARTY
# Index : 259 Past Index : 258
# -3648.8819999995467
# 3RD PARTY)
# (3RD PARTY
# Index : 263 Past Index : 262
# -3288.2490000000034
# 3RD PARTY)
# (3RD PARTY
# Index : 274 Past Index : 273
# -2510.7889999995095
# 3RD PARTY)
# (3RD PARTY
# Index : 280 Past Index : 279
# -4130.677000000003
# 3RD PARTY)
# (3RD PARTY
# Index : 297 Past Index : 296
# -4704.286
# 3RD PARTY)
# (3RD PARTY
# Index : 332 Past Index : 331
# -4842.201000000001
# 3RD PARTY)
# (TRUMP
# Index : 334 Past Index : 333
# -2502.441000000108
# TRUMP)
# (3RD PARTY
# Index : 336 Past Index : 335
# -4796.054000000004
# 3RD PARTY)
# (3RD PARTY
# Index : 362 Past Index : 361
# -4849.516000000003
# 3RD PARTY)
# (3RD PARTY
# Index : 369 Past Index : 368
# -4941.235000000001
# 3RD PARTY)
# (3RD PARTY
# Index : 485 Past Index : 484
# -4955.3080000000045
# 3RD PARTY)
# (TRUMP
# Index : 524 Past Index : 523
# -4840.73499999987
# TRUMP)
# (3RD PARTY
# Index : 526 Past Index : 525
# -4985.881000000001
# 3RD PARTY)
# (TRUMP
# Index : 529 Past Index : 528
# -4776.337000000291
# TRUMP)
# 20215.65600000025 TRUMP LOST
# 6956.512000000046 Trump to Biden
# 13259.144000000204 Trump to Third
# 5456.885000000213 BIDEN LOST
# 3530.7619999998715 Biden to Trump
# 1926.1230000003416 Biden to Third
# 98070.76399999915 3RD PARTY LOST
# 81906.734999999 Third to Biden
# 16164.02900000017 Third to Trump
# 3425.7500000001746 BIDEN

# %%
findfraud('MI_president')
# Out:
# (TRUMP
# Index : 28 Past Index : 27
# -5420.489999999991
# TRUMP)
# (3RD PARTY
# Index : 37 Past Index : 36
# -608.9249999999993
# 3RD PARTY)
# (TRUMP
# Index : 40 Past Index : 39
# -542.7700000000186
# TRUMP)
# (BIDEN
# Index : 47 Past Index : 46
# -624.4500000000116
# BIDEN)
# (3RD PARTY
# Index : 49 Past Index : 48
# -757.1280000000006
# 3RD PARTY)
# (3RD PARTY
# Index : 68 Past Index : 67
# -1039.6690000000017
# 3RD PARTY)
# (3RD PARTY
# Index : 71 Past Index : 70
# -898.9360000000015
# 3RD PARTY)
# (3RD PARTY
# Index : 78 Past Index : 77
# -1056.362000000001
# 3RD PARTY)
# (3RD PARTY
# Index : 83 Past Index : 82
# -2287.9010000000017
# 3RD PARTY)
# (3RD PARTY
# Index : 93 Past Index : 92
# -968.6949999999997
# 3RD PARTY)
# (3RD PARTY
# Index : 103 Past Index : 102
# -1453.1720000000023
# 3RD PARTY)
# (BIDEN
# Index : 104 Past Index : 103
# -1494.155999999959
# BIDEN)
# (3RD PARTY
# Index : 107 Past Index : 106
# -1506.2930000000015
# 3RD PARTY)
# (BIDEN
# Index : 108 Past Index : 107
# -1127.9340000000084
# BIDEN)
# (3RD PARTY
# Index : 112 Past Index : 111
# -1586.6360000000022
# 3RD PARTY)
# (3RD PARTY
# Index : 116 Past Index : 115
# -1791.3050000000003
# 3RD PARTY)
# (3RD PARTY
# Index : 119 Past Index : 118
# -1736.8199999999997
# 3RD PARTY)
# (BIDEN
# Index : 142 Past Index : 141
# -1917.859999999986
# BIDEN)
# (3RD PARTY
# Index : 143 Past Index : 142
# -2031.0769999999975
# 3RD PARTY)
# (3RD PARTY
# Index : 147 Past Index : 146
# -2056.017
# 3RD PARTY)
# (3RD PARTY
# Index : 165 Past Index : 164
# -1710.5949999997465
# 3RD PARTY)
# (BIDEN
# Index : 166 Past Index : 165
# -1369.9590000000317
# BIDEN)
# (3RD PARTY
# Index : 169 Past Index : 168
# -2250.5580000000045
# 3RD PARTY)
# (3RD PARTY
# Index : 183 Past Index : 182
# -2446.1860000000015
# 3RD PARTY)
# (BIDEN
# Index : 186 Past Index : 185
# -1332.4920000000857
# BIDEN)
# (3RD PARTY
# Index : 187 Past Index : 186
# -2473.879000000001
# 3RD PARTY)
# (BIDEN
# Index : 213 Past Index : 212
# -2315.563000000082
# BIDEN)
# (3RD PARTY
# Index : 216 Past Index : 215
# -2451.851999999999
# 3RD PARTY)
# (3RD PARTY
# Index : 228 Past Index : 227
# -2517.360000000008
# 3RD PARTY)
# (3RD PARTY
# Index : 241 Past Index : 240
# -2775.599000000322
# 3RD PARTY)
# (3RD PARTY
# Index : 246 Past Index : 245
# -2477.0589999996882
# 3RD PARTY)
# (3RD PARTY
# Index : 291 Past Index : 290
# -2785.2470000003595
# 3RD PARTY)
# (3RD PARTY
# Index : 310 Past Index : 309
# -3291.5639999999985
# 3RD PARTY)
# (BIDEN
# Index : 313 Past Index : 312
# -2241.8349999999627
# BIDEN)
# (3RD PARTY
# Index : 323 Past Index : 322
# -3349.9590000000026
# 3RD PARTY)
# (3RD PARTY
# Index : 326 Past Index : 325
# -3296.2670000003855
# 3RD PARTY)
# (3RD PARTY
# Index : 336 Past Index : 335
# -3379.1070000000036
# 3RD PARTY)
# (TRUMP
# Index : 337 Past Index : 336
# -1929.2639999999665
# TRUMP)
# (3RD PARTY
# Index : 338 Past Index : 337
# -3292.5030000000042
# 3RD PARTY)
# (BIDEN
# Index : 340 Past Index : 339
# -3225.215000000084
# BIDEN)
# (3RD PARTY
# Index : 358 Past Index : 357
# -3171.547000000006
# 3RD PARTY)
# (3RD PARTY
# Index : 374 Past Index : 373
# -3719.8700000000026
# 3RD PARTY)
# (3RD PARTY
# Index : 384 Past Index : 383
# -3734.389000000003
# 3RD PARTY)
# (TRUMP
# Index : 385 Past Index : 384
# -2528.5780000002123
# TRUMP)
# (3RD PARTY
# Index : 392 Past Index : 391
# -3450.616000000009
# 3RD PARTY)
# (3RD PARTY
# Index : 403 Past Index : 402
# -3847.9820000000036
# 3RD PARTY)
# (3RD PARTY
# Index : 409 Past Index : 408
# -4040.8139999999985
# 3RD PARTY)
# (BIDEN
# Index : 419 Past Index : 418
# -2441.9600000001956
# BIDEN)
# (3RD PARTY
# Index : 420 Past Index : 419
# -3147.7369999995426
# 3RD PARTY)
# (BIDEN
# Index : 426 Past Index : 425
# -2774.0870000000577
# BIDEN)
# (3RD PARTY
# Index : 430 Past Index : 429
# -3377.425000000003
# 3RD PARTY)
# (BIDEN
# Index : 432 Past Index : 431
# -3384.625999999931
# BIDEN)
# (TRUMP
# Index : 433 Past Index : 432
# -2428.8340000002645
# TRUMP)
# (3RD PARTY
# Index : 435 Past Index : 434
# -4270.175000000003
# 3RD PARTY)
# (3RD PARTY
# Index : 438 Past Index : 437
# -4311.948000000004
# 3RD PARTY)
# (3RD PARTY
# Index : 443 Past Index : 442
# -4051.7900000004884
# 3RD PARTY)
# (3RD PARTY
# Index : 446 Past Index : 445
# -3655.8550000000105
# 3RD PARTY)
# (3RD PARTY
# Index : 452 Past Index : 451
# -4286.987999999998
# 3RD PARTY)
# (3RD PARTY
# Index : 458 Past Index : 457
# -4480.9360000000015
# 3RD PARTY)
# (3RD PARTY
# Index : 468 Past Index : 467
# -4441.135000000009
# 3RD PARTY)
# (3RD PARTY
# Index : 470 Past Index : 469
# -4660.029999999999
# 3RD PARTY)
# (3RD PARTY
# Index : 481 Past Index : 480
# -3998.0560000000114
# 3RD PARTY)
# (3RD PARTY
# Index : 485 Past Index : 484
# -4642.437999999995
# 3RD PARTY)
# (TRUMP
# Index : 495 Past Index : 494
# -3957.223999999929
# TRUMP)
# (3RD PARTY
# Index : 496 Past Index : 495
# -4959.715000000011
# 3RD PARTY)
# (3RD PARTY
# Index : 502 Past Index : 501
# -5014.108000000007
# 3RD PARTY)
# (3RD PARTY
# Index : 516 Past Index : 515
# -4758.759999999995
# 3RD PARTY)
# (3RD PARTY
# Index : 521 Past Index : 520
# -5136.254000000015
# 3RD PARTY)
# 16807.160000000382 TRUMP LOST
# 9395.204000000726 Trump to Biden
# 7411.955999999656 Trump to Third
# 24250.137000000395 BIDEN LOST
# 11981.314000000828 Biden to Trump
# 12268.822999999567 Biden to Third
# 149435.23900000064 3RD PARTY LOST
# 124803.46400000044 Third to Biden
# 24631.775000000212 Third to Trump
# 2586.1100000001024 TRUMP

# %%
findfraud('PA_president')
# Out:
# (3RD PARTY
# Index : 19 Past Index : 18
# -527.2170000000006
# 3RD PARTY)
# (3RD PARTY
# Index : 22 Past Index : 21
# -645.0230000000001
# 3RD PARTY)
# (3RD PARTY
# Index : 32 Past Index : 31
# -954.7500000000009
# 3RD PARTY)
# (3RD PARTY
# Index : 40 Past Index : 39
# -1020.6390000000001
# 3RD PARTY)
# (3RD PARTY
# Index : 49 Past Index : 48
# -824.246000000001
# 3RD PARTY)
# (TRUMP
# Index : 51 Past Index : 50
# -127915.92100000003
# TRUMP)
# (3RD PARTY
# Index : 52 Past Index : 51
# -707.3580000000875
# 3RD PARTY)
# (3RD PARTY
# Index : 59 Past Index : 58
# -764.5410000000002
# 3RD PARTY)
# (3RD PARTY
# Index : 61 Past Index : 60
# -706.2530000000006
# 3RD PARTY)
# (3RD PARTY
# Index : 66 Past Index : 65
# -768.023000000001
# 3RD PARTY)
# (BIDEN
# Index : 76 Past Index : 75
# -905.5259999999544
# BIDEN)
# (3RD PARTY
# Index : 85 Past Index : 84
# -1077.7960000000003
# 3RD PARTY)
# (3RD PARTY
# Index : 99 Past Index : 98
# -1351.3370000000032
# 3RD PARTY)
# (3RD PARTY
# Index : 107 Past Index : 106
# -852.5490000000027
# 3RD PARTY)
# (3RD PARTY
# Index : 116 Past Index : 115
# -1323.4790000001885
# 3RD PARTY)
# (BIDEN
# Index : 122 Past Index : 121
# -1669.6140000000596
# BIDEN)
# (3RD PARTY
# Index : 125 Past Index : 124
# -1575.6869999998053
# 3RD PARTY)
# (3RD PARTY
# Index : 129 Past Index : 128
# -1142.7710000000006
# 3RD PARTY)
# (3RD PARTY
# Index : 133 Past Index : 132
# -1916.2529999997714
# 3RD PARTY)
# (3RD PARTY
# Index : 140 Past Index : 139
# -2130.2130000002435
# 3RD PARTY)
# (3RD PARTY
# Index : 146 Past Index : 145
# -2108.902999999751
# 3RD PARTY)
# (3RD PARTY
# Index : 151 Past Index : 150
# -2275.041000000001
# 3RD PARTY)
# (TRUMP
# Index : 152 Past Index : 151
# -2140.7009999998845
# TRUMP)
# (3RD PARTY
# Index : 165 Past Index : 164
# -1761.4710000000123
# 3RD PARTY)
# (3RD PARTY
# Index : 167 Past Index : 166
# -2635.252999999997
# 3RD PARTY)
# (3RD PARTY
# Index : 169 Past Index : 168
# -2698.2119999999995
# 3RD PARTY)
# (BIDEN
# Index : 179 Past Index : 178
# -2355.4490000000224
# BIDEN)
# (3RD PARTY
# Index : 182 Past Index : 181
# -8062.403000000006
# 3RD PARTY)
# (TRUMP
# Index : 188 Past Index : 187
# -17876.567999999737
# TRUMP)
# (BIDEN
# Index : 217 Past Index : 216
# -2788.381000000052
# BIDEN)
# (3RD PARTY
# Index : 218 Past Index : 217
# -3463.435000000005
# 3RD PARTY)
# (3RD PARTY
# Index : 230 Past Index : 229
# -3865.6740000004356
# 3RD PARTY)
# (3RD PARTY
# Index : 233 Past Index : 232
# -5780.392000000436
# 3RD PARTY)
# (3RD PARTY
# Index : 254 Past Index : 253
# -3868.258000000511
# 3RD PARTY)
# (3RD PARTY
# Index : 259 Past Index : 258
# -4513.853999999999
# 3RD PARTY)
# (3RD PARTY
# Index : 270 Past Index : 269
# -4405.502999999451
# 3RD PARTY)
# (3RD PARTY
# Index : 273 Past Index : 272
# -4921.398000000569
# 3RD PARTY)
# (BIDEN
# Index : 274 Past Index : 273
# -3243.9920000000857
# BIDEN)
# (3RD PARTY
# Index : 275 Past Index : 274
# -4956.17100000057
# 3RD PARTY)
# (3RD PARTY
# Index : 277 Past Index : 276
# -4448.862000000008
# 3RD PARTY)
# (3RD PARTY
# Index : 282 Past Index : 281
# -5284.073000000004
# 3RD PARTY)
# (TRUMP
# Index : 288 Past Index : 287
# -2873.68200000003
# TRUMP)
# (3RD PARTY
# Index : 289 Past Index : 288
# -4882.9690000006085
# 3RD PARTY)
# (TRUMP
# Index : 291 Past Index : 290
# -3098.4860000000335
# TRUMP)
# (3RD PARTY
# Index : 293 Past Index : 292
# -4412.589000000007
# 3RD PARTY)
# (3RD PARTY
# Index : 303 Past Index : 302
# -5526.541999999376
# 3RD PARTY)
# (3RD PARTY
# Index : 312 Past Index : 311
# -5665.406000000643
# 3RD PARTY)
# (3RD PARTY
# Index : 332 Past Index : 331
# -5760.347999999358
# 3RD PARTY)
# (TRUMP
# Index : 337 Past Index : 336
# -3095.43600000022
# TRUMP)
# (3RD PARTY
# Index : 348 Past Index : 347
# -5872.199999999342
# 3RD PARTY)
# (3RD PARTY
# Index : 354 Past Index : 353
# -5938.625
# 3RD PARTY)
# (BIDEN
# Index : 355 Past Index : 354
# -4949.3769999993965
# BIDEN)
# (3RD PARTY
# Index : 358 Past Index : 357
# -5916.716
# 3RD PARTY)
# (BIDEN
# Index : 359 Past Index : 358
# -4945.759000000078
# BIDEN)
# (3RD PARTY
# Index : 364 Past Index : 363
# -5976.5350000000035
# 3RD PARTY)
# (TRUMP
# Index : 365 Past Index : 364
# -3746.2309999996796
# TRUMP)
# (3RD PARTY
# Index : 371 Past Index : 370
# -5930.387000000002
# 3RD PARTY)
# (3RD PARTY
# Index : 378 Past Index : 377
# -6062.903000000006
# 3RD PARTY)
# (3RD PARTY
# Index : 384 Past Index : 383
# -6193.589000000007
# 3RD PARTY)
# (3RD PARTY
# Index : 395 Past Index : 394
# -6227.456999999995
# 3RD PARTY)
# (3RD PARTY
# Index : 408 Past Index : 407
# -6315.167000000001
# 3RD PARTY)
# (TRUMP
# Index : 412 Past Index : 411
# -5197.353000000119
# TRUMP)
# (3RD PARTY
# Index : 432 Past Index : 431
# -6364.036999999997
# 3RD PARTY)
# (TRUMP
# Index : 438 Past Index : 437
# -4321.899000000209
# TRUMP)
# (3RD PARTY
# Index : 441 Past Index : 440
# -6384.978000000003
# 3RD PARTY)
# (TRUMP
# Index : 443 Past Index : 442
# -6335.189000000246
# TRUMP)
# (3RD PARTY
# Index : 447 Past Index : 446
# -6441.996000000014
# 3RD PARTY)
# (3RD PARTY
# Index : 454 Past Index : 453
# -6441.899000000005
# 3RD PARTY)
# (TRUMP
# Index : 455 Past Index : 454
# -4709.541000000201
# TRUMP)
# (3RD PARTY
# Index : 472 Past Index : 471
# -6597.915000000008
# 3RD PARTY)
# (TRUMP
# Index : 499 Past Index : 498
# -6437.06100000022
# TRUMP)
# (3RD PARTY
# Index : 509 Past Index : 508
# -6608.346000000005
# 3RD PARTY)
# (TRUMP
# Index : 510 Past Index : 509
# -5156.983000000007
# TRUMP)
# (3RD PARTY
# Index : 518 Past Index : 517
# -6724.179000000004
# 3RD PARTY)
# (TRUMP
# Index : 522 Past Index : 521
# -6082.663000000175
# TRUMP)
# (3RD PARTY
# Index : 578 Past Index : 577
# -6764.697000000015
# 3RD PARTY)
# (TRUMP
# Index : 600 Past Index : 599
# -4668.118999999948
# TRUMP)
# (3RD PARTY
# Index : 617 Past Index : 616
# -6794.467000000004
# 3RD PARTY)
# (BIDEN
# Index : 619 Past Index : 618
# -6555.151000000071
# BIDEN)
# (3RD PARTY
# Index : 620 Past Index : 619
# -6848.013000000006
# 3RD PARTY)
# 88769.8330000007 TRUMP LOST
# 49718.495999999344 Trump to Biden
# 39051.33700000135 Trump to Third
# 27413.24899999972 BIDEN LOST
# 7159.232000000076 Biden to Trump
# 20254.016999999643 Biden to Third
# 229988.99800000124 3RD PARTY LOST
# 223071.20900000114 Third to Biden
# 6917.789000000117 Third to Trump
# 42559.26399999927 BIDEN

# %%
lostvotes('PA_president')
# Out:
# Index : 2 Past Index : 1
# -77
# Index : 4 Past Index : 3
# -11
# Index : 48 Past Index : 47
# -239804
# Index : 56 Past Index : 55
# -586189
# -187542.07999999996 TRUMP
# -613071.5320000001 BIDEN
# -25467.387999999948 THIRD
# -826081
